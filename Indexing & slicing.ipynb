# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40])
print(arr[0])  # 10
print(arr[-1]) # 40
# Out:
# 10
# 40

# %%
arr
# Out:
# array([10, 20, 30, 40])

# %%
b = arr[2:4]

# %%
b
# Out:
# array([30, 40])

# %%
b[0] = 333333333

# %%
b
# Out:
# array([333333333,        40])

# %%
arr
# Out:
# array([       10,        20, 333333333,        40])

# %% [markdown]
# Slicing returns a view, not a copy! Changes affect the original array

# %%
arr1 = np.array([1 , 66 ,74,32, 646, 34, 62])

# %%
arr1[[1,4,6]]  #1,4,6 are indices
# Out:
# array([ 66, 646,  62])

# %%
arr1[arr1>35]  #>35 every element showing
# Out:
# array([ 66,  74, 646,  62])
