# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df['Actor'] ## Single column (as Series)
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df[['Actor' , 'Film']]  #Multiple columns (as DataFrame)
# Out:
#                  Actor                      Film
# 0       Shah Rukh Khan                   Pathaan
# 1          Salman Khan           Tiger Zinda Hai
# 2           Aamir Khan                    Dangal
# 3        Ranbir Kapoor                Brahmastra
# 4        Ranveer Singh                 Padmaavat
# 5   Ayushmann Khurrana                 Andhadhun
# 6        Rajkummar Rao                     Stree
# 7       Hrithik Roshan                       War
# 8         Akshay Kumar                Good Newwz
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2
# 10        Varun Dhawan     Badrinath Ki Dulhania
# 11       Vicky Kaushal  Uri: The Surgical Strike

# %%
df.loc[0]  # First row (by row labels)
# Out:
# Actor                   Shah Rukh Khan
# Film                           Pathaan
# Year                              2023
# Genre                           Action
# BoxOffice(INR Crore)              1050
# IMDb                               7.2
# Name: 0, dtype: object

# %%
df.iloc[0] # First row (by position basically index)
# Out:
# Actor                   Shah Rukh Khan
# Film                           Pathaan
# Year                              2023
# Genre                           Action
# BoxOffice(INR Crore)              1050
# IMDb                               7.2
# Name: 0, dtype: object

# %%
df.loc[0:2 , ['Actor' , 'IMDb' , 'Film' ]]
# Out:
#             Actor  IMDb             Film
# 0  Shah Rukh Khan   7.2          Pathaan
# 1     Salman Khan   6.0  Tiger Zinda Hai
# 2      Aamir Khan   8.4           Dangal

# %%
df.iloc[0:2 , 0:2]
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai

# %%
df.at[0, "Actor"]       # Fast label-based access
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[0, 1]           # Fast position-based access
# Out:
# 'Pathaan'

# %%
df[df['IMDb']>7]['Actor']
# Out:
# 0         Shah Rukh Khan
# 2             Aamir Khan
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df[(df['IMDb']>6) & (df['Year']>2018)]
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
df.query("Year > 2018 and IMDb > 6")
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
#Dynamic column names:   (like this)
#col = "Age"
#df.query(f"{col} > 25")

# %%
# can use @ to reference Python variables
#To pass external variables into .query():
#LIKE THIS->
#age_limit = 30
#df.query("age > @age_limit")

# %%
#CHAINED COMPARISIONS
df.query("7.2<IMDb<8.4")
# Out:
#                  Actor                      Film  Year          Genre  \
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 5                    111   8.3
# 6                    180   7.5
# 11                   342   8.2

# %%
#.copy() helps in copying a edited data when assigned to a real data (to make sure the original data doesnt gets manipulated)

# %%
#.query() returns a copy, not a view
#The result is a new DataFrame. Changes won't affect the original unless reassigned:
#filtered = df.query("age < 50")
